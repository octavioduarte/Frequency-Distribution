# %% [markdown]
# ### Distribuição de frequência -  O que é? Onde vive e o que come? 🗒️
#
#
#  Distribuição de frequência é uma maneira de visualizarmos como os dados de uma determinado variável estão distribuídos. É uma entre outras alternativas (como histogramas por exemplo) para visualizarmos possíveis concentrações de dados em determinado conjunto ou até mesmo concentrações de dados de forma individual analisando registro por registro (apesar desta ser menos comum).
#
#  Vai além de simplesmente contarmos quantas vezes determinado registro aparece - É um conceito fundamental para tomadas de decisão, detectar possíveis tendências em determinado grupo de dados e etc... Vamos ver um pouco mais sobre isso neste texto:

# %% [markdown]
# #### Por que eu preciso saber como os dados da minha variável estão distribuídos?
#
#  Imagine um contexto onde você precisa criar um algoritmo de machine learning que classifica através de dados históricos se uma pessoa é propensa ou não a ter insuficiência cardíaca.
#
#  Além de entender as possíveis relações é também importante endermos possíveis concentrações de dados comparando eles com a nossa variável de saída - Por exemplo: Compreender se dentro do grupo de pacientes que tiverem insuficiência cariáca eu tenho maior concentração de pessoas em determinada idade e/ou faixa etária?
#
#  As técnicas de: distribuição de frequência, distribuição de dados e histogramas são diferentes formas visuais de enxergarmos isso, vamos ver o exemplo de cada uma:

# %% [markdown]
# #### Distribuição de frequência
#
# Grave essa breve explicação pois distribuição de frequência se resume a isso: **Distribuição de frequência é a forma tabular de visualizar como os dados de determinada variável estão distribuídos**. (tabular = tabela).
#
# Seguindo o contexto vamos criar uma tabela com dados ficticios sobre pessoas que tiveram ou não insuficiência cardíaca:
#
#
#
# | Nome             | Idade | Gênero    | Pressão Arterial | Colesterol | Insuficiência Cardíaca |
# |------------------|-------|-----------|------------------|------------|------------------------|
# | João Silva       | 55    | Masculino | 130/80           | 210        | Sim                    |
# | Maria Santos     | 62    | Feminino  | 140/90           | 190        | Não                    |
# | Pedro Oliveira   | 45    | Masculino | 125/78           | 180        | Não                    |
# | Ana Costa        | 70    | Feminino  | 150/95           | 220        | Sim                    |
# | Carlos Souza     | 50    | Masculino | 135/85           | 200        | Não                    |
# | Juliana Lima     | 58    | Feminino  | 145/88           | 195        | Sim                    |
# | André Santos     | 48    | Masculino | 128/82           | 185        | Não                    |
# | Beatriz Almeida  | 65    | Feminino  | 155/100          | 240        | Sim                    |
# | Marcos Oliveira  | 52    | Masculino | 133/84           | 205        | Não                    |
# | Renata Silva     | 60    | Feminino  | 148/92           | 210        | Não                    |
# | Felipe Costa     | 42    | Masculino | 123/75           | 175        | Não                    |
# | Laura Santos     | 68    | Feminino  | 152/98           | 230        | Sim                    |
# | Thiago Ferreira  | 55    | Masculino | 137/87           | 195        | Não                    |
# | Carolina Lima    | 57    | Feminino  | 143/89           | 200        | Sim                    |
# | Eduardo Souza    | 47    | Masculino | 130/81           | 190        | Não                    |
# | Gabriel Silva    | 50    | Masculino | 132/83           | 198        | Não                    |
# | Luiza Oliveira   | 55    | Feminino  | 147/91           | 215        | Sim                    |
# | Rafael Almeida   | 40    | Masculino | 120/76           | 170        | Não                    |
# | Marina Santos    | 63    | Feminino  | 149/93           | 225        | Sim                    |
# | Lucas Costa      | 45    | Masculino | 126/79           | 182        | Não                    |
# | Fernanda Lima    | 59    | Feminino  | 146/90           | 197        | Sim                    |
# | Gustavo Oliveira | 53    | Masculino | 134/86           | 203        | Não                    |
# | Mariana Silva    | 58    | Feminino  | 144/88           | 199        | Sim                    |
# | André Costa      | 48    | Masculino | 129/81           | 188        | Não                    |
# | Vanessa Souza    | 42    | Feminino  | 125/77           | 180        | Não                    |
#
#
#
#  Certo como o propósito do nosso modelo é identificar se a pessoa terá insuficiência cardiáca  faz mais sentido eu visualizar o "universo" de pessoas deste grupo, certo?! Vamos fazer isso:
#
#
# | Nome             | Idade | Gênero    | Pressão Arterial | Colesterol | Insuficiência Cardíaca |
# |------------------|-------|-----------|------------------|------------|------------------------|
# | João Silva       | 55    | Masculino | 130/80           | 210        | Sim                    |
# | Ana Costa        | 70    | Feminino  | 150/95           | 220        | Sim                    |
# | Juliana Lima     | 58    | Feminino  | 145/88           | 195        | Sim                    |
# | Beatriz Almeida  | 65    | Feminino  | 155/100          | 240        | Sim                    |
# | Laura Santos     | 68    | Feminino  | 152/98           | 230        | Sim                    |
# | Carolina Lima    | 57    | Feminino  | 143/89           | 200        | Sim                    |
# | Luiza Oliveira   | 55    | Feminino  | 147/91           | 215        | Sim                    |
# | Marina Santos    | 63    | Feminino  | 149/93           | 225        | Sim                    |
# | Fernanda Lima    | 59    | Feminino  | 146/90           | 197        | Sim                    |
# | Mariana Silva    | 58    | Feminino  | 144/88           | 199        | Sim                    |
#
#
# Agora se eu **desejo visualizar a distribuição de frequência** dos meus dados olhando a variável idade eu teria algo assim:
#
# | face | fi | fr  |
# |------|----|-----|
# | 55   | 2  | 0.2 |
# | 70   | 1  | 0.1 |
# | 58   | 2  | 0.2 |
# | 65   | 1  | 0.1 |
# | 68   | 1  | 0.1 |
# | 57   | 1  | 0.1 |
# | 63   | 1  | 0.1 |
# | 59   | 1  | 0.1 |
#
# * `face`: O valor da amostra que desejo visualizar.
#
# * `fi`: Conhecido como `frequência absolula` ou `frequência simples` é a quantidade de vezes em que a Face é exibida.
#
# * `fr`: É o percentual que o `fi` representa em relação a soma das frequências a fórmula seria:
#
#     `fri = fi/n (onde n é a soma de fi)`

# %% [markdown]
# #### Distribuição de frequência com classes
#
#    Distribuição de frequência com classes são **geralmente** aplicadas em [variáveis quantitativas contínuas](https://7meia.co/2024/07/03/variaveis-quantitativas-e-qualitativas) - Isso ocorre pois o conceito de uma variável quantitativa contínua se resume a diferentes valores que oscilam dentro de um determinado intervalo podendo até mesmo ser infinito, então concorda que criar uma tabela de distribuição de frequência simples para uma variável onde seus valores sofrem grande variação é inviável? Por exemplo: Imagine que ao invés de analisar os 25 pacientes da nossa tabela ficticia acima tivéssemos milhões de registros, por tanto, dividimos nossos dados em grupos que consistem em intervalos entre 2 valores.
#
#
#  A distribuição de frequência com classes consiste em criar classes que vão agrupar os dados da nossa variável - A ideia é analisarmos a frequência de uma forma mais abrangente e consequentemente menos individual.
#
#
# #### Separando os valores da nossa variável em classes
#
#
# <br/>
#
# > ##### Quantas classes devemos ter?
#
#   Para separarmos nossos valores em classes podemos adotar uma de  duas estratégias, ou no olhômetro 👁️ mesmo, ou seja, depois de extrair os valores aplico um range que julgo coerente e seguimos a vida, ou podemos aplicar algumas técnicas - Não é sobre certo ou errado aqui e sim sobre termos diferentes alternativas para um processo, mas evidentemente que na maioria dos casos seguindo algumas técnicas matemáticas o resultado é mais efetivo.
#
#
#   Vamos seguir com as técnicas por aqui para que você tenha um exemplo - A primeira delas é saber em quantas classes devo dividir meus dados e para isso podemos aplicar a `Fórmula de Sturges`:
#
#
# ~~~python
#      ​k = 1 + 3.3 . log(n)
# ~~~
#
#
#  `n`:  é o total de registros da amostra - No nosso caso é 25
#
#
# Resolvendo a fórmula temos:  5,61 - (Arredondando) Oodemos afirmar que segundo a `Fórmula de Sturges` devemos ter 6 classes
#
#
# <br/>
#
# > ##### Qual deve ser o intervalo entre cada classe?
#
#  Ok nessa altura já sabemos que devemos ter 6 classes, mas qual deve ser o intervalo entre seus valores? A pergunta que desejo responder aqui: Tenho 6 classes qual deve ser o valor inicial e final de cada uma para que eu determine seus intervalos? Para isso também existe uma técnica que podemos aplicar, veja a fórmula:
#
#
# ~~~python
#     Ai = At / k
# ~~~
#
# <br/>
#
# * `Ai`: Amplitude do intervalo
#
# * `At`: Amplitude total = Maior número do intervalo - Menor número do intervalo
#
# * `k`:  Número de classes
#
#
# Resolvendo a fórmula temos:
#
# Menor idade é 40 e maior idade é 70.
#
# Ai = (70 - 40) / 6
#
# O resultado da conta acima é 5, por tanto devemos ter 6 classes onde cada intervalo deve ter 5 anos. Nossa tabela de distribuição de frequência utilizando classes fica desse jeito:
#
#
# | classes | fi | fr   |
# |---------|----|------|
# | 40 ├ 45 | 3  | 0.12 |
# | 45 ├ 50 | 5  | 0.2  |
# | 50 ├ 55 | 4  | 0.16 |
# | 55 ├ 60 | 7  | 0.28 |
# | 60 ├ 65 | 3  | 0.12 |
# | 65 ├ 70 | 2  | 0.08 |
# | 70 ├ 75 | 1  | 0.04 |
#
#
# > O simbolo `├` diz que o valor a esquerda está incluído no intervalo enquanto o valor a direita **não** está, leia-se:
#
# ~~~
#  incluso ├ excluso
# ~~~
#
#
#  Repare que tivemos 7 classes ao contrário das 6 estabelecidas pela `Fórmula de Sturges`, isso é possível em conjuntos de dados muito pequenos pois o `n` (total de registros) que determina o total de classes pode não ser suficiente para determinar o total de classes - Neste caso adicionamos mais uma classe de 70 a 75.
#
#
#  Com o boxplot abaixo é possível ver que um valor acima deste ultimo intervalo entre 70 ├ 75 75 é considerado um outlier - O que pode nos levar a concluir que 7 é um número mais propicio para o total de classes

# %%
import pandas as pd 
import numpy as np

FAKE_DATA = 76 

data = np.array([55,62, 45, FAKE_DATA, 50, 58, 48, 65, 52, 60, 42, 68, 55, 57, 47, 50, 55, 40, 63, 45, 59, 53, 58, 48, 42])

df = pd.DataFrame(data)

df.boxplot(grid=False);

# %% [markdown]
# Aprendemos neste texto:
#
# - O que é distribuição de frequência
#
# - Qual a utilidade da distribuição de frequência
#
# -  Algumas siglas comuns em textos da comunidade de cientista de dados como `fi`, `fr` `Ai`, `At` etc..
#
#
# - Como montar uma tabela de visualização de frequência utilizando técnicas como `Fórmula de Sturges`
#
#
# Visualizar a `distribuição de frequência` é uma etapa fundamental que costuma ser usada na `análise exploratória dos dados` - Depois de aplicarmos essa estratégia com os dados acima para a coluna idade somos capazes de identificar onde existe uma maior e menor concentração de dados por faixa-etária o que é muito útil para nos familiarizarmos com nossos dados - Esta técnica pode ser aplicada em quaisquer variáveis quantitativas contínuas a fim de entendermos melhor a seu respeito.
#
# Concorda que  em um cenário realista dentro deste mesmo contexto com um maior conjunto de dados poderíemos concluir cientificamente falando quais faixa-etárias são mais propensas a terem insuficiência cardiaca o que nos ajuda no processo de treinamento de um modelo de machine learning ou até mesmo gera insights para profissionais da árae de negócio.
