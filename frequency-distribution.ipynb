# %% [markdown]
# ### Frequency Distribution 🗒️
#
# Frequency distribution is a way to visualize how data from a certain variable is distributed. It is one among several alternatives (such as histograms, for example) to visualize possible concentrations of data in a specific set or even concentrations of data individually by analyzing each record (although this is less common).
#
# It goes beyond simply counting how many times a particular record appears - It is a fundamental concept for decision-making, detecting possible trends in a specific group of data, and so on... Let's explore more about this in the following text:

# %% [markdown]
# #### Why do I need to know how my variable's data is distributed?
#
# Imagine a scenario where you need to create a machine learning algorithm that classifies whether a person is likely to have heart failure based on historical data.
#
# In addition to understanding possible relationships, it's also important to identify potential data concentrations by comparing them with our output variable. For example, understanding if there is a higher concentration of people of a certain age or age group among patients who have heart failure.
#
# There are different ways to visualize data distribution, and one of them is **frequency distribution**. Let's delve into it in more detail:

# %% [markdown]
# #### Frequency Distribution
#
# Take note of this brief explanation because frequency distribution boils down to this: **Frequency distribution is the tabular form of visualizing how data from a certain variable are distributed.** (tabular = table).
#
# Following this context, we will create a table with fictitious data about people who have or have not had heart failure:
#
#
# | Name             | Age   | Gender    | Blood Pressure   | Cholesterol| Heart Failure          |
# |------------------|-------|-----------|------------------|------------|------------------------|
# | João Silva       | 55    | Male      | 130/80           | 210        | Yes                    |
# | Maria Santos     | 62    | Female    | 140/90           | 190        | No                     |
# | Pedro Oliveira   | 45    | Male      | 125/78           | 180        | No                     |
# | Ana Costa        | 70    | Female    | 150/95           | 220        | Yes                    |
# | Carlos Souza     | 50    | Male      | 135/85           | 200        | No                     |
# | Juliana Lima     | 58    | Female    | 145/88           | 195        | Yes                    |
# | André Santos     | 48    | Male      | 128/82           | 185        | No                     |
# | Beatriz Almeida  | 65    | Female    | 155/100          | 240        | Yes                    |
# | Marcos Oliveira  | 52    | Male      | 133/84           | 205        | No                     |
# | Renata Silva     | 60    | Female    | 148/92           | 210        | No                     |
# | Felipe Costa     | 42    | Male      | 123/75           | 175        | No                     |
# | Laura Santos     | 68    | Female    | 152/98           | 230        | Yes                    |
# | Thiago Ferreira  | 55    | Male      | 137/87           | 195        | No                     |
# | Carolina Lima    | 57    | Female    | 143/89           | 200        | Yes                    |
# | Eduardo Souza    | 47    | Male      | 130/81           | 190        | No                     |
# | Gabriel Silva    | 50    | Male      | 132/83           | 198        | No                     |
# | Luiza Oliveira   | 55    | Female    | 147/91           | 215        | Yes                    |
# | Rafael Almeida   | 40    | Male      | 120/76           | 170        | No                     |
# | Marina Santos    | 63    | Female    | 149/93           | 225        | Yes                    |
# | Lucas Costa      | 45    | Male      | 126/79           | 182        | No                     |
# | Fernanda Lima    | 59    | Female    | 146/90           | 197        | Yes                    |
# | Gustavo Oliveira | 53    | Male      | 134/86           | 203        | No                     |
# | Mariana Silva    | 58    | Female    | 144/88           | 199        | Yes                    |
# | André Costa      | 48    | Male      | 129/81           | 188        | No                     |
# | Vanessa Souza    | 42    | Female    | 125/77           | 180        | No                    |
#
#
#
# Since the purpose of our model is to identify if a person will have heart failure, it makes more sense for me to visualize the "universe" of people in this group, right?! Let's do that:
#
# | Name             | Age   | Gender    | Blood Pressure   | Cholesterol | Heart Failure          |
# |------------------|-------|-----------|------------------|------------ |------------------------|
# | João Silva       | 55    | Male      | 130/80           | 210         | Yes                    |
# | Ana Costa        | 70    | Female    | 150/95           | 220         | Yes                    |
# | Juliana Lima     | 58    | Female    | 145/88           | 195         | Yes                    |
# | Beatriz Almeida  | 65    | Female    | 155/100          | 240         | Yes                    |
# | Laura Santos     | 68    | Female    | 152/98           | 230         | Yes                    |
# | Carolina Lima    | 57    | Female    | 143/89           | 200         | Yes                    |
# | Luiza Oliveira   | 55    | Female    | 147/91           | 215         | Yes                    |
# | Marina Santos    | 63    | Female    | 149/93           | 225         | Yes                    |
# | Fernanda Lima    | 59    | Female    | 146/90           | 197         | Yes                    |
# | Mariana Silva    | 58    | Female    | 144/88           | 199         | Yes                    |
#
#
# Now, if I want to **visualize the frequency distribution** of my data looking at the variable age, it would look like this:
#
# | face | fi | fr  |
# |------|----|-----|
# | 55   | 2  | 0.2 |
# | 70   | 1  | 0.1 |
# | 58   | 2  | 0.2 |
# | 65   | 1  | 0.1 |
# | 68   | 1  | 0.1 |
# | 57   | 1  | 0.1 |
# | 63   | 1  | 0.1 |
# | 59   | 1  | 0.1 |
#
# * face: The sample value I want to visualize.
#
# * fi: Known as absolute frequency or simple frequency, it's the number of times the Face is displayed.
#
# * fr: It's the percentage that fi represents in relation to the sum of frequencies. The formula would be:
#
#   fri = fi/n (where n is the sum of fi)

# %% [markdown]
# #### Frequency distribution with class
#
#    Frequency distribution with classes is **generally** applied to continuous quantitative variables. This is because the concept of a continuous quantitative variable involves different values that fluctuate within a certain range, potentially infinitely. Therefore, do you agree that creating a simple frequency distribution table for a variable with large variations in its values is impractical? For example: Imagine instead of analyzing the 25 patients from our fictitious table above, we had millions of records. Therefore, we divide our data into groups consisting of intervals between 2 values.
#
#
#
#  Frequency distribution with classes involves creating classes that group the data from our variable. The idea is to analyze the frequency in a broader and less individual manner.
#
#
# #### Separating the values of our variable into classes
#
#
# <br/>
#
# > ##### How many classes should we have?
#
#  To separate our values into classes, we can adopt one of two strategies. One is to eyeball it 👁️, meaning after extracting the values, I apply a range that I find appropriate and move forward. The other strategy involves applying some techniques. It's not about right or wrong here; it's about having different alternatives for a process. However, in most cases, following certain mathematical techniques yields more effective results.
#
# Let's proceed with the techniques here so that you have an example. The first one is knowing how many classes I should divide my data into, and for that, we can apply the `Sturges Formula`:
#
# ~~~python
#      ​k = 1 + 3.3 . log(n)
# ~~~
#
#
#  `n`: It's the total number of records in the sample - In our case, it's 25.
#
#
# Resolvendo a fórmula temos:  5,61 - (Arredondando) Oodemos afirmar que segundo a `Fórmula de Sturges` devemos ter 6 classes
#
#
# <br/>
#
# > ##### What should be the interval between each class?
#
#  Ok, at this point, we know we should have 6 classes, but what should be the interval between their values? The question I want to answer here is: If I have 6 classes, what should be the starting and ending values for each one to determine their intervals? There's also a technique we can apply for this, let's see the formula:
#
#
# ~~~python
#     Ai = At / k
# ~~~
#
# <br/>
#
# * Ai: Interval amplitude
#
# * At: Total amplitude = Largest number in the range - Smallest number in the range
#
# * k: Number of classes
#
#
# Solving the formula, we have:
#
# Smallest age is 40 and largest age is 70.
#
# Ai = (70 - 40) / 6
#
# The result of the calculation above is 5, so we should have 6 classes where each interval spans 5 years. Our frequency distribution table using classes looks like this:
#
#
# | classes | fi | fr   |
# |---------|----|------|
# | 40 ├ 45 | 3  | 0.12 |
# | 45 ├ 50 | 5  | 0.2  |
# | 50 ├ 55 | 4  | 0.16 |
# | 55 ├ 60 | 7  | 0.28 |
# | 60 ├ 65 | 3  | 0.12 |
# | 65 ├ 70 | 2  | 0.08 |
# | 70 ├ 75 | 1  | 0.04 |
#
#
# > The symbol ├ indicates that the value on the left is included in the interval while the value on the right is not, read as:
#
# ~~~
# inclusive ├ exclusive
# ~~~
#
#
# Notice that we ended up with 7 classes instead of the 6 established by the Sturges' Formula. This is possible in very small datasets because the total number of records nn, which determines the number of classes, may not be sufficient to precisely determine the total number of classes. In this case, we added an additional class from 70 to 75.
#
# With the boxplot below, it's possible to see that a value above this last interval, between 70 ├ 75, is considered an outlier. This might lead us to conclude that 7 is a more suitable number for the total number of classes.

# %%
import pandas as pd 
import numpy as np

FAKE_DATA = 76 

data = np.array([55,62, 45, FAKE_DATA, 50, 58, 48, 65, 52, 60, 42, 68, 55, 57, 47, 50, 55, 40, 63, 45, 59, 53, 58, 48, 42])

df = pd.DataFrame(data)

df.boxplot(grid=False);

# %% [markdown]
# We learn in this text:
#
# * What frequency distribution is
#
# * The utility of frequency distribution
#
# * Some common acronyms in texts from the data scientist community such as fi, fr, Ai, At, etc.
#
# * How to create a frequency visualization table using techniques like the Sturges' Formula
#
# Visualizing frequency distribution is a fundamental step often used in exploratory data analysis. After applying this strategy to the data above for the age column, we are able to identify where there is a higher and lower concentration of data by age group, which is very useful for becoming familiar with our data. This technique can be applied to any continuous quantitative variables to better understand them.
#
# Do you agree that in a realistic scenario within this same context, with a larger dataset, we could scientifically conclude which age groups are more prone to having heart failure? This helps us in the process of training a machine learning model or even generates insights for business professionals.
